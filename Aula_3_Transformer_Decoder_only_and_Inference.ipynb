# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielaugustavo/LLM/blob/main/Aula_3_Transformer_Decoder_only_and_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 3 - Transformer *decoder-only*
#
# Nesta aula você irá modificar o Transformer *decoder-only* fornecido a seguir.
# Observe que em um *decoder-only* não existe:
#
# *   cross-attention
# *   encoder separado
#
# e é utilizado com *auto-regressão*.
#
# ## Objetivo
#
#
# ## Exercício
#
# Neste exercício você deve:
#
# 1.   carregar o seu conjunto de documentos
# 2.   treinar e usar (ou carregar) um tokenizador
# 3.   fazer treino de um modelo decoder-only
# 4.   incluir no loop de treino, inferência usando máxima probabilidade
# 5.   incluir no loop de treino, inferência usando amostragem com temperatura

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# %% [markdown]
# # Passo 1: carregar conjunto de documentos

# %%
import re
import os
import unicodedata

# 1. Defina aqui o nome do arquivo (verifique se a extensão .txt é necessária)
caminho_arquivo = "/content/books_pt_pos"

def clean_custom(text):
    # a. Converter para minúsculo
    text = text.lower()

    # b. Remover acentuação (Normalização NFD)
    # Decompõe caracteres acentuados e filtra apenas os caracteres base
    text = unicodedata.normalize('NFD', text)
    text = "".join([c for c in text if unicodedata.category(c) != 'Mn'])

    # c. Manter apenas ASCII básico (Segurança adicional)
    text = text.encode("ascii", errors="ignore").decode()

    # d. Regex para remover a vírgula e manter apenas o desejado
    # Removida a vírgula da lista [^...]
    text = re.sub(r"[^a-z0-9 .:;!?'\-]", "", text)

    return text

# 2. Leitura direta do sistema de arquivos
documentos = []

if os.path.exists(caminho_arquivo):
    with open(caminho_arquivo, "r", encoding="utf-8") as f:
        for linha in f:
            # Aplica a nossa nova limpeza
            texto_limpo = clean_custom(linha.strip())
            if len(texto_limpo) > 0:
                documentos.append(texto_limpo)

    print(f"Sucesso! Arquivo '{caminho_arquivo}' carregado e processado.")
else:
    print(f"Erro: O arquivo '{caminho_arquivo}' não foi encontrado.")
    print("Certifique-se de que o nome está correto na barra lateral 📁")

print("-" * 30)
print("Total documentos:", len(documentos))
print("Amostra (Sample):")
for i, doc in enumerate(documentos[:5]):
    print(f"{i+1}: {doc}")
# Out:
# Sucesso! Arquivo '/content/books_pt_pos' carregado e processado.
# ------------------------------
# Total documentos: 1000
# Amostra (Sample):
# 1: enfim o final da serie chegou e me deixou arrebatada e emocionada. um final cheio de amor e lembrancas perfeito para uma serie tao emocionante e intensa. mauricio era o ultimo dos lafaietes solteiro mas eleonora arrebatou seu coracao ainda que nao estivesse nos seus planos. ele desde sempre soube o que queria e correu atras para realizar os seus sonhos. eleonora nao foi uma mocinha facil e docil. maumau ao contrario decidido intenso e apaixonado. uma historia cativante que vai te envolvendo. o amor nao tem idade e nao ve traumas e preconceitos ele vai arrebatando e tudo supera e foi exatamente isso que a autora foi nos revelando aos poucos. uma historia de superacao perdao e aceitacao. um final repleto de figuras queridas e cheio de lagrimas e emocao. estou definitivamente de ressaca literaria os lafaietes sempre terao um pedacinho do meu coracao. super recomendo.
# 2: aiai! agora ficamos orfaos dos lafaiete  a historia de amor entre mauricio e eleonora nos leva ao final da serie dos lafaiete... se nao fosse por maumau eleonora nao ganharia minha simpatia mas a autora como sempre conseguiu nos envolver nessa historia de amor de um jeito so dela que aos poucos eleonora foi me ganhando. as consequencias de um passado as vezes trazem mazelas dificeis de serem superadas mas com a presenca do verdadeiro amor felizmente superamos e vencemos essa barreira. mauricio insistiu no amor por eleonora e ao final foi plenamente premiado com a felicidade e com o fofissimo bernardo sim eu imagino como e esse mini lafaiete  parabens lara voce lacrou com o final da serie! leitura recomendada!
# 3: lara smithe fechou a serie com chave de ouroque amor mais lindo contagiante foi perfeito ficou um gosto de quero mais parabens voce merece
# 4: mais uma vez a lara smithe nos deixa de boca aberta sem saber o que dizer a historia e maravilhosa e nos mostra que para o amor nao existe idade basta deixar o coracao aberto e o preconceito de lado. a historia de eleonor e mauricio e linda. amei o afonso ele e perfeito como pai chefe de familia e como homem queria eu ter um homem como ele. que pena que acabou a serie os lafaetes.
# 5: otima ideia: aglutinar os livros dos quatro irmaos lafaiete e nos oferecer a saga completa. personagens apaixonantes e apaixonados fortes determinados. uma leitura que prende. um mergulho em um mar de aventuras. bem escrito. bem dosado. parabens a autora!

# %% [markdown]
# # Passo 2: Carregar ou treinar um tokenizador

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordLevel
from tokenizers.trainers import WordLevelTrainer
from tokenizers.pre_tokenizers import Whitespace
import random
import re

##### Insira aqui o código para treinar o seu TOKENIZER
# Defina o seu tokenizador
tokenizer = Tokenizer(WordLevel(unk_token="[UNK]"))
tokenizer.pre_tokenizer = Whitespace()
trainer = WordLevelTrainer(
    vocab_size=500,
    special_tokens=["[PAD]", "[UNK]", "[BOS]", "[EOS]"]
)
# Treino do tokenizador
tokenizer.train_from_iterator(documentos, trainer)

# Funções auxiliares para transitar entre tokens textuais e ids de tokens
def encode(text):
    ids = tokenizer.encode("[BOS] " + text + " [EOS]").ids
    return torch.tensor(ids, dtype=torch.long)

def decode(ids):
    return tokenizer.decode(ids.tolist())

vocab_size = tokenizer.get_vocab_size()

# %% [markdown]
# ## Definição do modelo Transformer Decoder-only

# %%
class DecoderOnlyTransformer(nn.Module):
    "Implementação de um transformer que tem somente a parte do decoder"
    def __init__(self, vocab_size, d_model=128, n_heads=4, num_layers=3, max_len=64):
        super().__init__()
        self.max_len = max_len

        self.token_emb = nn.Embedding(vocab_size, d_model)
        self.pos_emb = nn.Embedding(max_len, d_model)

        layer = nn.TransformerDecoderLayer(
            d_model=d_model,
            nhead=n_heads,
            dim_feedforward=256,
            batch_first=True
        )
        self.decoder = nn.TransformerDecoder(layer, num_layers=num_layers)
        self.lm_head = nn.Linear(d_model, vocab_size)

    def forward(self, x):
        B, T = x.shape
        pos = torch.arange(T, device=x.device).unsqueeze(0)

        h = self.token_emb(x) + self.pos_emb(pos)

        # Máscara causal
        mask = torch.triu(torch.ones(T, T, device=x.device), diagonal=1).bool()

        out = self.decoder(h, h, tgt_mask=mask)
        logits = self.lm_head(out)
        return logits

# %% [markdown]
# # Códigos de inferência

# %% [markdown]
# ## Código de inferência simples: token com maior probabilidade

# %%
def max_prob_sampling(logits):
    next_token = logits.argmax(dim=-1)
    return next_token.unsqueeze(0)

# %% [markdown]
# ## Código de inferência avançada: amostragem com temperatura

# %%
import torch

# Inferência (com temperature e top_p)
def sampling(logits, top_p=0.9, top_k=None, temperature=1.0):
    # Ajusta pela temperatura
    logits = logits / temperature

    # Se top_k for especificado, filtra por top_k primeiro
    if top_k is not None:
        # Ensure top_k is not larger than the vocabulary size
        k_to_use = min(top_k, logits.size(-1))
        # Get the top_k values and indices
        v, _ = torch.topk(logits, k_to_use)
        # Set logits of all values smaller than the k-th value to -inf
        logits[logits < v[:, [-1]]] = float('-inf')

    # Ordena os logits
    sorted_logits, sorted_indices = torch.sort(logits, descending=True)
    cumulative_probs = torch.softmax(sorted_logits, dim=-1).cumsum(dim=-1)

    # Mascara tokens acima do top_p
    mask = cumulative_probs > top_p
    # Garante que ao menos um token permaneça
    mask[..., 1:] = mask[..., :-1].clone()
    mask[..., 0] = False

    filtered_logits = sorted_logits.masked_fill(mask, float('-inf'))
    probs = torch.softmax(filtered_logits, dim=-1)

    # Amostra o token
    sampled_idx = torch.multinomial(probs, num_samples=1)

    # Converte para índice na tabela original
    next_token = sorted_indices[sampled_idx]

    return next_token


def generate(prompt, next_token_function, max_new_tokens=20, top_k=None, top_p=0.9, temperature=1.0):
    model.eval()
    x = encode(prompt).unsqueeze(0).to(device)

    for _ in range(max_new_tokens):
        logits = model(x)[:, -1, :]  # pega apenas o último passo

        # Passa os parâmetros de amostragem se a função for top_p_sampling
        if next_token_function == sampling:
            next_token = next_token_function(logits.squeeze(0), top_k=top_k, top_p=top_p, temperature=temperature)
        else:
            next_token = next_token_function(logits.squeeze(0))

        x = torch.cat([x, next_token.unsqueeze(0)], dim=1)

        if next_token.item() == tokenizer.token_to_id("[EOS]"):
            break

    return decode(x[0])

# %% [markdown]
# # 4. Fazer treino de modelo: códigos de treino

# %%
# Função auxiliar para gerar batches de exemplos para treino
def sample_batch(batch_size=16, max_len=20):
    batch = random.sample(documentos, batch_size)
    tokenized = [encode(t) for t in batch]

    max_t = min(max(len(x) for x in tokenized), max_len)
    padded = []

    for x in tokenized:
        x = x[:max_t]
        pad_len = max_t - len(x)
        if pad_len > 0:
            x = torch.cat([x, torch.zeros(pad_len, dtype=torch.long)])
        padded.append(x)

    return torch.stack(padded)

################################
device = "cuda" if torch.cuda.is_available() else "cpu"
model = DecoderOnlyTransformer(vocab_size).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5)
#################################

steps = 10000

for step in range(1, steps + 1):
    model.train()
    batch = sample_batch().to(device)

    logits = model(batch[:, :-1])
    loss = F.cross_entropy(
        logits.reshape(-1, vocab_size),
        batch[:, 1:].reshape(-1),
        ignore_index=tokenizer.token_to_id("[PAD]")
    )

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if step % 50 == 0:
        ppl = torch.exp(loss).item()
        print(f"[step {step}] loss={loss.item():.4f}, ppl={ppl:.2f}")

    if step % 100 == 0:
        print("Generated text:")
        print(generate("gostei muito achei que", next_token_function=sampling, temperature=0.9, top_p=0.8 ))
        print("--------------------------------------")

print("Training completed.")
# Out:
# [step 50] loss=6.0885, ppl=440.77
# [step 100] loss=5.7347, ppl=309.42
# Generated text:
# gostei muito achei que de los ate certo possivel onde esse recomendado fa dele dos mulheres essencial bem sao dia entrega ao mesmo outras
# --------------------------------------
# [step 150] loss=5.4589, ppl=234.83
# [step 200] loss=5.2063, ppl=182.41
# Generated text:
# gostei muito achei que todos dias infancia momentos mulher lhe apos gostei algo das riqueza !!! lani quanto isso presente leia sofia dentro pena
# --------------------------------------
# [step 250] loss=5.2085, ppl=182.82
# [step 300] loss=5.1210, ppl=167.50
# Generated text:
# gostei muito achei que ainda esse conta dela lhe adorei toda autor diversos mudar e comecei michelle achei nos parabens amazon outras
# --------------------------------------
# [step 350] loss=4.7979, ppl=121.26
# [step 400] loss=4.8712, ppl=130.48
# Generated text:
# gostei muito achei que a autor estado amigos vidas nada e serie rapida . indico esse filme livro meu pelas . livro etc
# --------------------------------------
# [step 450] loss=4.6748, ppl=107.22
# [step 500] loss=4.6151, ppl=101.00
# Generated text:
# gostei muito achei que inicio parabens muitos melhores ensinamentos esse tudo quando parabens maravilhoso financeira o essa e
# --------------------------------------
# [step 550] loss=4.6794, ppl=107.70
# [step 600] loss=4.6199, ppl=101.48
# Generated text:
# gostei muito achei que criancas qualidade esse agradavel melhor sera conteudo recomendo ainda dicas tao livros no autor
# --------------------------------------
# [step 650] loss=4.8227, ppl=124.30
# [step 700] loss=4.3269, ppl=75.71
# Generated text:
# gostei muito achei que alem este por exemplos vou fazer . forma envolvente fogo todo e da e livro trabalho inicio
# --------------------------------------
# [step 750] loss=4.6937, ppl=109.26
# [step 800] loss=4.4403, ppl=84.80
# Generated text:
# gostei muito achei que melhor envolvente podemos mudar . podem nao um ler melhores ... entrega
# --------------------------------------
# [step 850] loss=4.5124, ppl=91.14
# [step 900] loss=4.4382, ppl=84.62
# Generated text:
# gostei muito achei que enredo certo autor vai de tenho ! nosso pessoa este mim ao felicidade gostei e
# --------------------------------------
# [step 950] loss=4.6375, ppl=103.28
# [step 1000] loss=4.3857, ppl=80.30
# Generated text:
# gostei muito achei que livro si capa e e fala e a na tempo apresenta la livro as um
# --------------------------------------
# [step 1050] loss=4.4390, ppl=84.69
# [step 1100] loss=4.2988, ppl=73.61
# Generated text:
# gostei muito achei que livro de e indico livro contar livro situacoes melhor todos escrito sempre . nada comprei de atraves facil
# --------------------------------------
# [step 1150] loss=4.3532, ppl=77.73
# [step 1200] loss=4.1688, ppl=64.64
# Generated text:
# gostei muito achei que livro muito se e foi extremamente o e dura
# --------------------------------------
# [step 1250] loss=4.5369, ppl=93.40
# [step 1300] loss=4.5407, ppl=93.76
# Generated text:
# gostei muito achei que titulo estoria livro a minha em e esse livro historia o recomendo de do dos pelas que
# --------------------------------------
# [step 1350] loss=4.5284, ppl=92.61
# [step 1400] loss=4.2812, ppl=72.33
# Generated text:
# gostei muito achei que ainda dinheiro livros ! e simples o serie da livro agradavel ja lhe dura a
# --------------------------------------
# [step 1450] loss=4.3630, ppl=78.49
# [step 1500] loss=4.5502, ppl=94.65
# Generated text:
# gostei muito achei que gostei tem a e livros que excelente historia livro de livro -
# --------------------------------------
# [step 1550] loss=4.5711, ppl=96.65
# [step 1600] loss=4.3137, ppl=74.71
# Generated text:
# gostei muito achei que o lido tem o o o muito - fa primeiro para me ser que agradavel por na nos
# --------------------------------------
# [step 1650] loss=4.1082, ppl=60.84
# [step 1700] loss=4.2345, ppl=69.03
# Generated text:
# gostei muito achei que livro de ... com uma e e de mudar . e com que que . para para e de
# --------------------------------------
# [step 1750] loss=4.3833, ppl=80.10
# [step 1800] loss=4.5664, ppl=96.19
# Generated text:
# gostei muito achei que mas a muito que de facil livro que . e de de
# --------------------------------------
# [step 1850] loss=4.3460, ppl=77.17
# [step 1900] loss=4.3471, ppl=77.25
# Generated text:
# gostei muito achei que livro consegue livro . de no . livro a da livro mas ser ler de estou que que
# --------------------------------------
# [step 1950] loss=4.3468, ppl=77.23
# [step 2000] loss=4.1919, ppl=66.15
# Generated text:
# gostei muito achei que seu a o facil pena importante do lee que o lee uma de que conteudo ha dizer melhor completamente de
# --------------------------------------
# [step 2050] loss=4.2885, ppl=72.86
# [step 2100] loss=4.3522, ppl=77.65
# Generated text:
# gostei muito achei que bom sobre de forma este nao como e esse agradavel pessoas fala sobre nada e da livro ler o dois
# --------------------------------------
# [step 2150] loss=3.9898, ppl=54.04
# [step 2200] loss=4.3034, ppl=73.95
# Generated text:
# gostei muito achei que e um final de de ela a do livros de eu com e e para
# --------------------------------------
# [step 2250] loss=4.2529, ppl=70.31
# [step 2300] loss=4.1566, ppl=63.85
# Generated text:
# gostei muito achei que vale final para consegue agradavel e pois para bom te no . a estou de
# --------------------------------------
# [step 2350] loss=4.2326, ppl=68.90
# [step 2400] loss=4.1225, ppl=61.71
# Generated text:
# gostei muito achei que muito da apenas
# --------------------------------------
# [step 2450] loss=3.9468, ppl=51.77
# [step 2500] loss=4.2747, ppl=71.86
# Generated text:
# gostei muito achei que simples forma autor faz o foi e essa ja que em ja tao amazon simples . e ... reflexao
# --------------------------------------
# [step 2550] loss=3.9135, ppl=50.07
# [step 2600] loss=3.8708, ppl=47.98
# Generated text:
# gostei muito achei que nos pra por seu os o primeiro o de . ! so a e
# --------------------------------------
# [step 2650] loss=4.0322, ppl=56.38
# [step 2700] loss=3.9636, ppl=52.65
# Generated text:
# gostei muito achei que paginas . facil leitor linda melhor simples . ser que . a mulheres . que em uma da
# --------------------------------------
# [step 2750] loss=4.1707, ppl=64.76
# [step 2800] loss=4.1169, ppl=61.37
# Generated text:
# gostei muito achei que livro livro que nos edicao . pelas anos conteudo que mas . tempo todas esta livro . muito rapida de
# --------------------------------------
# [step 2850] loss=4.0813, ppl=59.23
# [step 2900] loss=3.8176, ppl=45.49
# Generated text:
# gostei muito achei que tecnicas boas - excelente mentalidade para recomendo um . . a esse eu seu faz os . me muito
# --------------------------------------
# [step 2950] loss=3.8536, ppl=47.16
# [step 3000] loss=3.7478, ppl=42.43
# Generated text:
# gostei muito achei que do quer muito sou livro que a que que a de que e sempre minha conteudo a biografia que vezes
# --------------------------------------
# [step 3050] loss=3.6923, ppl=40.14
# [step 3100] loss=3.4847, ppl=32.61
# Generated text:
# gostei muito achei que sera um para de narrativa de fantastico toda nos eu incrivel ela pode o livro fala das de muitos
# --------------------------------------
# [step 3150] loss=3.4733, ppl=32.24
# [step 3200] loss=3.6508, ppl=38.51
# Generated text:
# gostei muito achei que inicio deste ! foi ideias . de como logo um livro livro fala livro nos quem nao de
# --------------------------------------
# [step 3250] loss=3.1924, ppl=24.35
# [step 3300] loss=3.6123, ppl=37.05
# Generated text:
# gostei muito achei que que que que te ler escrito para todos que atraves personagens livros pessoal ela escrito primeiro com que que lee
# --------------------------------------
# [step 3350] loss=3.2954, ppl=26.99
# [step 3400] loss=3.5363, ppl=34.34
# Generated text:
# gostei muito achei que por amor nossos de onde exemplos livro de futuro de ter de ler os excelente . de a de de
# --------------------------------------
# [step 3450] loss=3.4135, ppl=30.37
# [step 3500] loss=3.5102, ppl=33.46
# Generated text:
# gostei muito achei que nova pena que a possui de e para que que ate consegue michelle tudo que historia que e que de
# --------------------------------------
# [step 3550] loss=3.4073, ppl=30.18
# [step 3600] loss=3.2444, ppl=25.65
# Generated text:
# gostei muito achei que que que nossos que linguagem que que que apresenta que se e linguagem que de possui para que sua guerra
# --------------------------------------
# [step 3650] loss=3.3718, ppl=29.13
# [step 3700] loss=3.1324, ppl=22.93
# Generated text:
# gostei muito achei que que .... que sempre e que em texto que que suas que acho que foi uma ter autor o que
# --------------------------------------
# [step 3750] loss=3.0245, ppl=20.58
# [step 3800] loss=3.0822, ppl=21.81
# Generated text:
# gostei muito achei que relacao que pela importante a ler que como minha final que do para em que obra melhor sobre que
# --------------------------------------
# [step 3850] loss=3.2836, ppl=26.67
# [step 3900] loss=2.9785, ppl=19.66
# Generated text:
# gostei muito achei que claro editora que ler humano rico que que com que a bem uma que em que que que os
# --------------------------------------
# [step 3950] loss=2.8719, ppl=17.67
# [step 4000] loss=3.1372, ppl=23.04
# Generated text:
# gostei muito achei que ler que que ler que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 4050] loss=2.9170, ppl=18.49
# [step 4100] loss=2.8996, ppl=18.17
# Generated text:
# gostei muito achei que que habitos que que que com em apenas que sao que que de que que em que que para
# --------------------------------------
# [step 4150] loss=2.7011, ppl=14.90
# [step 4200] loss=2.7305, ppl=15.34
# Generated text:
# gostei muito achei que no foi que que lado que que e que facil que muito ja que que dois livros que que este
# --------------------------------------
# [step 4250] loss=2.7506, ppl=15.65
# [step 4300] loss=2.7102, ppl=15.03
# Generated text:
# gostei muito achei que sem nem linda autor inicio outros dar que dois a muito lado amor que chegou tive final onde ele
# --------------------------------------
# [step 4350] loss=2.8539, ppl=17.36
# [step 4400] loss=2.6988, ppl=14.86
# Generated text:
# gostei muito achei que que que que que que que com que que que que que que que que que que que que que
# --------------------------------------
# [step 4450] loss=2.6212, ppl=13.75
# [step 4500] loss=2.7505, ppl=15.65
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 4550] loss=2.9305, ppl=18.74
# [step 4600] loss=2.5907, ppl=13.34
# Generated text:
# gostei muito achei que fantastico principalmente livro livro dois livro de diferente gente historia de inicio chegou de de objetivo tempo como de seu
# --------------------------------------
# [step 4650] loss=2.8971, ppl=18.12
# [step 4700] loss=2.5686, ppl=13.05
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 4750] loss=2.7803, ppl=16.12
# [step 4800] loss=2.8800, ppl=17.81
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 4850] loss=2.3890, ppl=10.90
# [step 4900] loss=2.4531, ppl=11.62
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 4950] loss=2.5554, ppl=12.88
# [step 5000] loss=2.6038, ppl=13.52
# Generated text:
# gostei muito achei que muito livro muito muito muito em livro alem em dos !! este muito super uma livro em mesmo
# --------------------------------------
# [step 5050] loss=2.4698, ppl=11.82
# [step 5100] loss=2.4158, ppl=11.20
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 5150] loss=2.2046, ppl=9.07
# [step 5200] loss=2.4497, ppl=11.58
# Generated text:
# gostei muito achei que excelente gosto que muito como de leitor que que suas que dura mente que falar que que que que
# --------------------------------------
# [step 5250] loss=2.4521, ppl=11.61
# [step 5300] loss=2.1125, ppl=8.27
# Generated text:
# gostei muito achei que para dia que que em com em em na diferente que facil que como para ler que que que
# --------------------------------------
# [step 5350] loss=2.3005, ppl=9.98
# [step 5400] loss=2.2783, ppl=9.76
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 5450] loss=2.2706, ppl=9.69
# [step 5500] loss=2.1627, ppl=8.69
# Generated text:
# gostei muito achei que de . que com bem que em muito que nao que lo que que que que que que que que
# --------------------------------------
# [step 5550] loss=2.2695, ppl=9.67
# [step 5600] loss=2.3275, ppl=10.25
# Generated text:
# gostei muito achei que que muito que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 5650] loss=1.9850, ppl=7.28
# [step 5700] loss=2.1810, ppl=8.86
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 5750] loss=1.9348, ppl=6.92
# [step 5800] loss=2.0304, ppl=7.62
# Generated text:
# gostei muito achei que de de de de de de de nem de de de de de de de de de de de de
# --------------------------------------
# [step 5850] loss=2.0175, ppl=7.52
# [step 5900] loss=2.0239, ppl=7.57
# Generated text:
# gostei muito achei que que que que que que que que muito que que que que que que que que que que que que
# --------------------------------------
# [step 5950] loss=2.2267, ppl=9.27
# [step 6000] loss=2.0413, ppl=7.70
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 6050] loss=2.0633, ppl=7.87
# [step 6100] loss=2.0874, ppl=8.06
# Generated text:
# gostei muito achei que de de que muito de de de que que livros que de como que de facil de que que de
# --------------------------------------
# [step 6150] loss=2.0165, ppl=7.51
# [step 6200] loss=2.2015, ppl=9.04
# Generated text:
# gostei muito achei que muito bom para muito bom quem muito bem como sim mas proprio que que que conteudo que bem que que
# --------------------------------------
# [step 6250] loss=2.0384, ppl=7.68
# [step 6300] loss=1.9905, ppl=7.32
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 6350] loss=1.8793, ppl=6.55
# [step 6400] loss=1.9786, ppl=7.23
# Generated text:
# gostei muito achei que de de nos de de de de ler de de de de de de de de de de de de
# --------------------------------------
# [step 6450] loss=1.8728, ppl=6.51
# [step 6500] loss=1.6857, ppl=5.40
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 6550] loss=1.9993, ppl=7.38
# [step 6600] loss=2.0046, ppl=7.42
# Generated text:
# gostei muito achei que que que que que que que muito que que me que que que que que que que que que que
# --------------------------------------
# [step 6650] loss=1.6323, ppl=5.12
# [step 6700] loss=1.9117, ppl=6.76
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 6750] loss=1.8177, ppl=6.16
# [step 6800] loss=1.9861, ppl=7.29
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 6850] loss=1.6407, ppl=5.16
# [step 6900] loss=2.0122, ppl=7.48
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 6950] loss=1.9061, ppl=6.73
# [step 7000] loss=1.8161, ppl=6.15
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 7050] loss=1.7115, ppl=5.54
# [step 7100] loss=1.6766, ppl=5.35
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 7150] loss=1.4021, ppl=4.06
# [step 7200] loss=1.6924, ppl=5.43
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 7250] loss=1.6251, ppl=5.08
# [step 7300] loss=1.6349, ppl=5.13
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 7350] loss=1.4214, ppl=4.14
# [step 7400] loss=1.5028, ppl=4.49
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 7450] loss=1.4926, ppl=4.45
# [step 7500] loss=1.6655, ppl=5.29
# Generated text:
# gostei muito achei que para
# --------------------------------------
# [step 7550] loss=1.4988, ppl=4.48
# [step 7600] loss=1.7444, ppl=5.72
# Generated text:
# gostei muito achei que dicas estamos livro muito apresenta muito leitura muito que muito muito bom que muito de muito gostei muito muito muito
# --------------------------------------
# [step 7650] loss=1.5559, ppl=4.74
# [step 7700] loss=1.4717, ppl=4.36
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 7750] loss=1.6230, ppl=5.07
# [step 7800] loss=1.2901, ppl=3.63
# Generated text:
# gostei muito achei que para interessantes que muito para muito para
# --------------------------------------
# [step 7850] loss=1.4975, ppl=4.47
# [step 7900] loss=1.6362, ppl=5.14
# Generated text:
# gostei muito achei que que que que muito que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 7950] loss=1.4944, ppl=4.46
# [step 8000] loss=1.4351, ppl=4.20
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 8050] loss=1.4357, ppl=4.20
# [step 8100] loss=1.4446, ppl=4.24
# Generated text:
# gostei muito achei que muito muito que muito muito muito muito que que que que que que que que muito que que que que
# --------------------------------------
# [step 8150] loss=1.4735, ppl=4.36
# [step 8200] loss=1.6395, ppl=5.15
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 8250] loss=1.1688, ppl=3.22
# [step 8300] loss=1.4129, ppl=4.11
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 8350] loss=1.4775, ppl=4.38
# [step 8400] loss=1.5611, ppl=4.76
# Generated text:
# gostei muito achei que que que que muito que que historia que que que que que que que que que que que que que
# --------------------------------------
# [step 8450] loss=1.6109, ppl=5.01
# [step 8500] loss=1.1882, ppl=3.28
# Generated text:
# gostei muito achei que que muito que muito que muito que que que que que que que que que muito que que que que
# --------------------------------------
# [step 8550] loss=1.5460, ppl=4.69
# [step 8600] loss=1.3420, ppl=3.83
# Generated text:
# gostei muito achei que muito deste muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito
# --------------------------------------
# [step 8650] loss=1.2572, ppl=3.52
# [step 8700] loss=1.1988, ppl=3.32
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 8750] loss=1.3342, ppl=3.80
# [step 8800] loss=1.2592, ppl=3.52
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 8850] loss=1.2365, ppl=3.44
# [step 8900] loss=1.3186, ppl=3.74
# Generated text:
# gostei muito achei que que boas que muito que muito que muito que muito que que que muito que muito que muito que que
# --------------------------------------
# [step 8950] loss=1.2098, ppl=3.35
# [step 9000] loss=1.1964, ppl=3.31
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 9050] loss=1.3035, ppl=3.68
# [step 9100] loss=1.4388, ppl=4.22
# Generated text:
# gostei muito achei que que ate ler conhecimento quer da vou muito que muito que que que que que muito que muito que que
# --------------------------------------
# [step 9150] loss=1.3220, ppl=3.75
# [step 9200] loss=1.0403, ppl=2.83
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 9250] loss=1.2062, ppl=3.34
# [step 9300] loss=1.2092, ppl=3.35
# Generated text:
# gostei muito achei que muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito
# --------------------------------------
# [step 9350] loss=1.0686, ppl=2.91
# [step 9400] loss=1.2447, ppl=3.47
# Generated text:
# gostei muito achei que que que que muito que muito muito que que que que que que que que que que que que que
# --------------------------------------
# [step 9450] loss=1.3772, ppl=3.96
# [step 9500] loss=1.1979, ppl=3.31
# Generated text:
# gostei muito achei que muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito muito
# --------------------------------------
# [step 9550] loss=1.1821, ppl=3.26
# [step 9600] loss=1.3504, ppl=3.86
# Generated text:
# gostei muito achei que que que que que que que facil que que que que que que que que que que que que que
# --------------------------------------
# [step 9650] loss=1.3422, ppl=3.83
# [step 9700] loss=1.0847, ppl=2.96
# Generated text:
# gostei muito achei que que super obras muito que muito que que que que que que que que que muito que que que que
# --------------------------------------
# [step 9750] loss=1.0902, ppl=2.97
# [step 9800] loss=1.1631, ppl=3.20
# Generated text:
# gostei muito achei que que que que que que que precisa que que que que que que que que que que que que que
# --------------------------------------
# [step 9850] loss=1.1187, ppl=3.06
# [step 9900] loss=1.2190, ppl=3.38
# Generated text:
# gostei muito achei que que que que que que que que que que que que que que que que que que que que que
# --------------------------------------
# [step 9950] loss=1.0002, ppl=2.72
# [step 10000] loss=1.1329, ppl=3.10
# Generated text:
# gostei muito achei que que que que muito que muito que muito que muito que que que muito que muito que muito que que
# --------------------------------------
# Training completed.

# %% [markdown]
# # Exercício: controle de temperatura, Top-K e Top-P
#
# Modifique o código a seguir para fazer a visualização de produção de tokens do modelo que você treinou.

# %%
# @title
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, Markdown

# -----------------------------
# Mock language-model logits
# -----------------------------
TOKENS = ["blue", "purple", "violet", "vio", "not", "Blue", "green", "gray", "grey", "black"]
BASE_LOGITS = np.array([6.0, 1.5, 0.5, 0.2, 0.2, 0.0, -5.0, -5.0, -5.0, -5.0])

def softmax(x):
    e = np.exp(x - np.max(x))
    return e / e.sum()

def apply_temperature(logits, temperature):
    return logits / max(temperature, 1e-5)

def apply_top_k(probs, k):
    if k >= len(probs):
        return probs
    idx = np.argsort(probs)[::-1]
    mask = np.zeros_like(probs)
    mask[idx[:k]] = 1
    probs = probs * mask
    return probs / probs.sum()

def apply_top_p(probs, p):
    idx = np.argsort(probs)[::-1]
    cumulative = np.cumsum(probs[idx])
    mask = cumulative <= p
    mask[np.argmax(mask)] = True
    new_probs = np.zeros_like(probs)
    new_probs[idx[mask]] = probs[idx[mask]]
    return new_probs / new_probs.sum()

# -----------------------------
# Widgets
# -----------------------------
prompt_dropdown = widgets.Dropdown(
    options=["Roses are red, violets are..."],
    value="Roses are red, violets are...",
    description="Prompt",
    layout=widgets.Layout(width="95%")
)

temperature_slider = widgets.FloatSlider(
    value=1.0, min=0.1, max=5.0, step=0.1,
    description="Temperatura",
    readout_format=".1f",
    layout=widgets.Layout(width="90%")
)

topk_slider = widgets.IntSlider(
    value=6, min=1, max=10, step=1,
    description="Top-K",
    layout=widgets.Layout(width="90%")
)

topp_slider = widgets.FloatSlider(
    value=1.0, min=0.1, max=1.0, step=0.05,
    description="Top-P",
    readout_format=".2f",
    layout=widgets.Layout(width="90%")
)

# -----------------------------
# Plot
# -----------------------------
output_plot = widgets.Output()

def update_plot(*args):
    with output_plot:
        output_plot.clear_output()

        logits = apply_temperature(BASE_LOGITS, temperature_slider.value)
        probs = softmax(logits)
        probs = apply_top_k(probs, topk_slider.value)
        probs = apply_top_p(probs, topp_slider.value)

        fig, ax = plt.subplots(figsize=(10, 4))
        bars = ax.bar(TOKENS, probs * 100)
        ax.set_ylim(0, 100)
        ax.set_ylabel("Probabilidade (%)")
        ax.set_title("Probabilidade do próximo token")

        for bar, p in zip(bars, probs):
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_height(),
                f"{p*100:.2f}%",
                ha="center",
                va="bottom",
                fontsize=9
            )

        plt.xticks(rotation=0)
        plt.show()

for w in [temperature_slider, topk_slider, topp_slider]:
    w.observe(update_plot, names="value")

# -----------------------------
# Collapsible explanation
# -----------------------------
accordion = widgets.Accordion(
    children=[widgets.HTML(
        """
        <ul>
          <li><b>Temperatura</b>: Controla aleatoriedade com mudança na escala dos logits.</li>
          <li><b>Top-K</b>: Restringe a amostra aos K tokens mais prováveis.</li>
          <li><b>Top-P</b>: Usa somente os menor conjunto de tokens que resultam em probabilidade acumulada até P.</li>
        </ul>
        """
    )]
)
accordion.set_title(0, "Entenda a visualização")

# -----------------------------
# Layout
# -----------------------------
controls = widgets.VBox([
    prompt_dropdown,
    widgets.HBox([temperature_slider]),
    widgets.HBox([topk_slider]),
    widgets.HBox([topp_slider])
])

display(Markdown("## Visualização de controle de Temperatura, Top-K e Top-P."))
display(widgets.VBox([
    widgets.HTML("<b>Parameters</b>"),
    controls,
    output_plot,
    accordion
]))

update_plot()
# Out:
# ## Visualização de controle de Temperatura, Top-K e Top-P.
# VBox(children=(HTML(value='<b>Parameters</b>'), VBox(children=(Dropdown(description='Prompt', layout=Layout(wi…
